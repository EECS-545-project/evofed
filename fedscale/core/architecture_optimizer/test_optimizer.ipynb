# %%
from util.init_model import OptResnet18
model = OptResnet18()

# %%
from optimizer import optimize
for key in model.state_dict().keys():
    print(key)
model = optimize(model, 0)
for key in model.state_dict().keys():
    print(key)
model = optimize(model, 1)
for key in model.state_dict().keys():
    print(key)
model = optimize(model, 2)
for key in model.state_dict().keys():
    print(key)
# Out:
# conv1.weight
# bn1.weight
# bn1.bias
# bn1.running_mean
# bn1.running_var
# bn1.num_batches_tracked
# layers.0.0.convs.0.weight
# layers.0.0.convs.1.weight
# layers.0.0.bns.0.weight
# layers.0.0.bns.0.bias
# layers.0.0.bns.0.running_mean
# layers.0.0.bns.0.running_var
# layers.0.0.bns.0.num_batches_tracked
# layers.0.0.bns.1.weight
# layers.0.0.bns.1.bias
# layers.0.0.bns.1.running_mean
# layers.0.0.bns.1.running_var
# layers.0.0.bns.1.num_batches_tracked
# layers.0.0.downsample.0.weight
# layers.0.0.downsample.1.weight
# layers.0.0.downsample.1.bias
# layers.0.0.downsample.1.running_mean
# layers.0.0.downsample.1.running_var
# layers.0.0.downsample.1.num_batches_tracked
# layers.0.1.convs.0.weight
# layers.0.1.convs.1.weight
# layers.0.1.bns.0.weight
# layers.0.1.bns.0.bias
# layers.0.1.bns.0.running_mean
# layers.0.1.bns.0.running_var
# layers.0.1.bns.0.num_batches_tracked
# layers.0.1.bns.1.weight
# layers.0.1.bns.1.bias
# layers.0.1.bns.1.running_mean
# layers.0.1.bns.1.running_var
# layers.0.1.bns.1.num_batches_tracked
# layers.1.0.convs.0.weight
# layers.1.0.convs.1.weight
# layers.1.0.bns.0.weight
# layers.1.0.bns.0.bias
# layers.1.0.bns.0.running_mean
# layers.1.0.bns.0.running_var
# layers.1.0.bns.0.num_batches_tracked
# layers.1.0.bns.1.weight
# layers.1.0.bns.1.bias
# layers.1.0.bns.1.running_mean
# layers.1.0.bns.1.running_var
# layers.1.0.bns.1.num_batches_tracked
# layers.1.0.downsample.0.weight
# layers.1.0.downsample.1.weight
# layers.1.0.downsample.1.bias
# layers.1.0.downsample.1.running_mean
# layers.1.0.downsample.1.running_var
# layers.1.0.downsample.1.num_batches_tracked
# layers.1.1.convs.0.weight
# layers.1.1.convs.1.weight
# layers.1.1.bns.0.weight
# layers.1.1.bns.0.bias
# layers.1.1.bns.0.running_mean
# layers.1.1.bns.0.running_var
# layers.1.1.bns.0.num_batches_tracked
# layers.1.1.bns.1.weight
# layers.1.1.bns.1.bias
# layers.1.1.bns.1.running_mean
# layers.1.1.bns.1.running_var
# layers.1.1.bns.1.num_batches_tracked
# layers.2.0.convs.0.weight
# layers.2.0.convs.1.weight
# layers.2.0.bns.0.weight
# layers.2.0.bns.0.bias
# layers.2.0.bns.0.running_mean
# layers.2.0.bns.0.running_var
# layers.2.0.bns.0.num_batches_tracked
# layers.2.0.bns.1.weight
# layers.2.0.bns.1.bias
# layers.2.0.bns.1.running_mean
# layers.2.0.bns.1.running_var
# layers.2.0.bns.1.num_batches_tracked
# layers.2.0.downsample.0.weight
# layers.2.0.downsample.1.weight
# layers.2.0.downsample.1.bias
# layers.2.0.downsample.1.running_mean
# layers.2.0.downsample.1.running_var
# layers.2.0.downsample.1.num_batches_tracked
# layers.2.1.convs.0.weight
# layers.2.1.convs.1.weight
# layers.2.1.bns.0.weight
# layers.2.1.bns.0.bias
# layers.2.1.bns.0.running_mean
# layers.2.1.bns.0.running_var
# layers.2.1.bns.0.num_batches_tracked
# layers.2.1.bns.1.weight
# layers.2.1.bns.1.bias
# layers.2.1.bns.1.running_mean
# layers.2.1.bns.1.running_var
# layers.2.1.bns.1.num_batches_tracked
# layers.3.0.convs.0.weight
# layers.3.0.convs.1.weight
# layers.3.0.bns.0.weight
# layers.3.0.bns.0.bias
# layers.3.0.bns.0.running_mean
# layers.3.0.bns.0.running_var
# layers.3.0.bns.0.num_batches_tracked
# layers.3.0.bns.1.weight
# layers.3.0.bns.1.bias
# layers.3.0.bns.1.running_mean
# layers.3.0.bns.1.running_var
# layers.3.0.bns.1.num_batches_tracked
# layers.3.0.downsample.0.weight
# layers.3.0.downsample.1.weight
# layers.3.0.downsample.1.bias
# layers.3.0.downsample.1.running_mean
# layers.3.0.downsample.1.running_var
# layers.3.0.downsample.1.num_batches_tracked
# layers.3.1.convs.0.weight
# layers.3.1.convs.1.weight
# layers.3.1.bns.0.weight
# layers.3.1.bns.0.bias
# layers.3.1.bns.0.running_mean
# layers.3.1.bns.0.running_var
# layers.3.1.bns.0.num_batches_tracked
# layers.3.1.bns.1.weight
# layers.3.1.bns.1.bias
# layers.3.1.bns.1.running_mean
# layers.3.1.bns.1.running_var
# layers.3.1.bns.1.num_batches_tracked
# fc.weight
# fc.bias
# Files already downloaded and verified
# Files already downloaded and verified
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e02c65c263e1> in <module>()
#       2 for key in model.state_dict().keys():
#       3     print(key)
# ----> 4 model = optimize(model, 0)
#       5 for key in model.state_dict().keys():
#       6     print(key)
#
# /home/yuxuan/Documents/Research/evofed/fedscale/core/architecture_optimizer/optimizer.py in optimize(model, opt_times)
#      11     manager.init_agent()
#      12     manager.init_model(model)
# ---> 13     # manager.save_model()
#      14     manager.load_policy(opt_times)
#      15     manager.optimize_model(False)
#
# AttributeError: 'NoneType' object has no attribute 'load_policy'
